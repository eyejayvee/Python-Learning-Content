# %% [markdown]
# ![image.png](attachment:d63b6dac-d303-4140-9972-e3786b26df1d.png)

# %% [markdown]
# # Whistle stop tour

# %%
# Import the pandas library
import pandas as pd

# DataFrames are often aliased as `df`, but in real-world situations, a meaningful is more appropriate
df = pd.read_csv("202312-divvy-tripdata.csv")

df.head(10)

# %%
# Let's get and idea of the number of rows and columns
df.shape

# %%
# What are the data types of each column?
df.dtypes

# %% [markdown]
# Pandas defines strings as `object`.

# %%
df.info

# %%
df.count()

# %% [markdown]
# Pandas will not count `NaN` values as you can see with columns that have a lower count value that the total number of rows in the dataframe.

# %%
# Let's look at the start and end station names, selecting the bottom 10 rows
start_end_stations = df[["start_station_name", "end_station_name"]]
start_end_stations.tail(10)

# %% [markdown]
# This is like (although not quite the same) writing the following SQL statement:
#
# ``` sql
# SELECT start_station,
#        end_station
#   FROM my_table
# ORDER BY start_station, end_station DESC
# LIMIT 10;
# ```
#
# You get the idea: less typing.
# ![image.png](attachment:8dcbc677-e5d9-4d41-bf32-593094f2da3a.png)

# %%
df.dropna()

# %%
df.dropna(axis=1)

# %%
df.fillna(0)
